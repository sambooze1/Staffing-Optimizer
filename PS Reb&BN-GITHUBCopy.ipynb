# %%
import gurobipy as gp
from gurobipy import GRB

# Data
cycle_times = [
    6.51,5.46,5.98,8.13,4.96,5.12,8.71,4.17,3.85,8.46,7.03,4.01,5.04,3.61,3.05,3.41
]
operator_counts = [20, 19, 18, 17, 16]
shift_hours = 9
n = len(cycle_times)

for total_ops in operator_counts:
    print(f'\n=== Total Operators: {total_ops} ===\n')
    
    # 1) Integer allocation
    m_int = gp.Model(f'Int_Alloc_{total_ops}')
    m_int.Params.OutputFlag = 0
    ops_int = m_int.addVars(n, vtype=GRB.INTEGER, lb=1, name='ops_int')
    mu_int = m_int.addVar(vtype=GRB.CONTINUOUS, name='mu_int')
    for i, T in enumerate(cycle_times):
        m_int.addConstr(60 * ops_int[i] >= mu_int * T)
    m_int.addConstr(ops_int.sum() == total_ops)
    m_int.setObjective(mu_int, GRB.MAXIMIZE)
    m_int.optimize()
    thr_int = mu_int.X
    daily_int = thr_int * shift_hours
    adj_daily_int = 0.72 * daily_int
    rates_int = [60 * ops_int[i].X / cycle_times[i] for i in range(n)]
    print('Integer Allocation:')
    print(f'▶ Throughput: {thr_int:.2f} u/hr, Output: {daily_int:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_int:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        print(f'|   {i+1:>2}    |  {int(ops_int[i].X):>3}  |   {rates_int[i]:>6.2f}  |')
    top3_int = sorted(range(n), key=lambda i: rates_int[i])[:3]
    print('Top 3 bottlenecks:')
    for idx in top3_int:
        print(f'  Station {idx+1}: {rates_int[idx]:.2f} u/hr')
    
    print('\n')
    
    # 2) Half-allocation
    m_half = gp.Model(f'Half_Alloc_{total_ops}')
    m_half.Params.OutputFlag = 0
    h_ops = m_half.addVars(n, vtype=GRB.INTEGER, lb=1, name='h_ops')
    mu_half = m_half.addVar(vtype=GRB.CONTINUOUS, name='mu_half')
    for i, T in enumerate(cycle_times):
        m_half.addConstr(60 * h_ops[i] >= mu_half * (2 * T))
    m_half.addConstr(h_ops.sum() == total_ops * 2)
    m_half.setObjective(mu_half, GRB.MAXIMIZE)
    m_half.optimize()
    thr_half = mu_half.X
    daily_half = thr_half * shift_hours
    adj_daily_half = 0.72 * daily_half
    rates_half = [(60 * (h_ops[i].X / 2)) / cycle_times[i] for i in range(n)]
    print('Half Allocation:')
    print(f'▶ Throughput: {thr_half:.2f} u/hr, Output: {daily_half:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_half:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        ops_val = h_ops[i].X / 2
        print(f'|   {i+1:>2}    | {ops_val:>5.2f} |   {rates_half[i]:>6.2f}  |')
    top3_half = sorted(range(n), key=lambda i: rates_half[i])[:3]
    print('Top 3 bottlenecks:')
    for idx in top3_half:
        print(f'  Station {idx+1}: {rates_half[idx]:.2f} u/hr')
    
    print('\n')
    
    # 3) Fractional allocation
    m_frac = gp.Model(f'Frac_Alloc_{total_ops}')
    m_frac.Params.OutputFlag = 0
    ops_frac = m_frac.addVars(n, vtype=GRB.CONTINUOUS, lb=0, name='ops_frac')
    mu_frac = m_frac.addVar(vtype=GRB.CONTINUOUS, name='mu_frac')
    for i, T in enumerate(cycle_times):
        m_frac.addConstr(60 * ops_frac[i] >= mu_frac * T)
    m_frac.addConstr(ops_frac.sum() == total_ops)
    m_frac.setObjective(mu_frac, GRB.MAXIMIZE)
    m_frac.optimize()
    thr_frac = mu_frac.X
    daily_frac = thr_frac * shift_hours
    adj_daily_frac = 0.72 * daily_frac
    rates_frac = [60 * ops_frac[i].X / cycle_times[i] for i in range(n)]
    print('Fractional Allocation:')
    print(f'▶ Throughput: {thr_frac:.2f} u/hr, Output: {daily_frac:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_frac:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        print(f'|   {i+1:>2}    | {ops_frac[i].X:>5.2f} |   {rates_frac[i]:>6.2f}  |')
    
    print('\n' + '-'*40 + '\n')
# Out:
# === Total Operators: 20 ===
#
# Set parameter Username
# Set parameter LicenseID to value 2663177
# Academic license - for non-commercial use only - expires 2026-05-09
# Integer Allocation:
# ▶ Throughput: 9.22 u/hr, Output: 82.9 units
# ▶ Adjusted for 28% PF&D: 59.7 units
# | Station |   Ops |  Units/hr |
# |    1    |    1  |     9.22  |
# |    2    |    1  |    10.99  |
# |    3    |    1  |    10.03  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.90  |
# |   14    |    1  |    16.62  |
# |   15    |    1  |    19.67  |
# |   16    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 1: 9.22 u/hr
#   Station 3: 10.03 u/hr
#   Station 2: 10.99 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 10.99 u/hr, Output: 98.9 units
# ▶ Adjusted for 28% PF&D: 71.2 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.00 |    10.99  |
# |    3    |  1.50 |    15.05  |
# |    4    |  1.50 |    11.07  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.00 |    11.72  |
# |    7    |  2.00 |    13.78  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.90  |
# |   14    |  1.00 |    16.62  |
# |   15    |  1.00 |    19.67  |
# |   16    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 2: 10.99 u/hr
#   Station 4: 11.07 u/hr
#   Station 6: 11.72 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 13.71 u/hr, Output: 123.4 units
# ▶ Adjusted for 28% PF&D: 88.9 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.49 |    13.71  |
# |    2    |  1.25 |    13.71  |
# |    3    |  1.37 |    13.71  |
# |    4    |  1.86 |    13.71  |
# |    5    |  1.13 |    13.71  |
# |    6    |  1.17 |    13.71  |
# |    7    |  1.99 |    13.71  |
# |    8    |  0.95 |    13.71  |
# |    9    |  0.88 |    13.71  |
# |   10    |  1.93 |    13.71  |
# |   11    |  1.61 |    13.71  |
# |   12    |  0.92 |    13.71  |
# |   13    |  1.15 |    13.71  |
# |   14    |  0.83 |    13.71  |
# |   15    |  0.70 |    13.71  |
# |   16    |  0.78 |    13.71  |
#
# ----------------------------------------
#
#
# === Total Operators: 19 ===
#
# Integer Allocation:
# ▶ Throughput: 8.53 u/hr, Output: 76.8 units
# ▶ Adjusted for 28% PF&D: 55.3 units
# | Station |   Ops |  Units/hr |
# |    1    |    1  |     9.22  |
# |    2    |    1  |    10.99  |
# |    3    |    1  |    10.03  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    1  |     8.53  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.90  |
# |   14    |    1  |    16.62  |
# |   15    |    1  |    19.67  |
# |   16    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 11: 8.53 u/hr
#   Station 1: 9.22 u/hr
#   Station 3: 10.03 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 10.33 u/hr, Output: 93.0 units
# ▶ Adjusted for 28% PF&D: 67.0 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.00 |    10.99  |
# |    3    |  1.50 |    15.05  |
# |    4    |  1.50 |    11.07  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.00 |    11.72  |
# |    7    |  1.50 |    10.33  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  1.50 |    10.64  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.90  |
# |   14    |  1.00 |    16.62  |
# |   15    |  1.00 |    19.67  |
# |   16    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 7: 10.33 u/hr
#   Station 10: 10.64 u/hr
#   Station 2: 10.99 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 13.03 u/hr, Output: 117.3 units
# ▶ Adjusted for 28% PF&D: 84.4 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.41 |    13.03  |
# |    2    |  1.19 |    13.03  |
# |    3    |  1.30 |    13.03  |
# |    4    |  1.77 |    13.03  |
# |    5    |  1.08 |    13.03  |
# |    6    |  1.11 |    13.03  |
# |    7    |  1.89 |    13.03  |
# |    8    |  0.91 |    13.03  |
# |    9    |  0.84 |    13.03  |
# |   10    |  1.84 |    13.03  |
# |   11    |  1.53 |    13.03  |
# |   12    |  0.87 |    13.03  |
# |   13    |  1.09 |    13.03  |
# |   14    |  0.78 |    13.03  |
# |   15    |  0.66 |    13.03  |
# |   16    |  0.74 |    13.03  |
#
# ----------------------------------------
#
#
# === Total Operators: 18 ===
#
# Integer Allocation:
# ▶ Throughput: 7.38 u/hr, Output: 66.4 units
# ▶ Adjusted for 28% PF&D: 47.8 units
# | Station |   Ops |  Units/hr |
# |    1    |    1  |     9.22  |
# |    2    |    1  |    10.99  |
# |    3    |    1  |    10.03  |
# |    4    |    1  |     7.38  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    1  |     8.53  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.90  |
# |   14    |    1  |    16.62  |
# |   15    |    1  |    19.67  |
# |   16    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 4: 7.38 u/hr
#   Station 11: 8.53 u/hr
#   Station 1: 9.22 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 9.84 u/hr, Output: 88.5 units
# ▶ Adjusted for 28% PF&D: 63.7 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.00 |    10.99  |
# |    3    |  1.00 |    10.03  |
# |    4    |  1.50 |    11.07  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.00 |    11.72  |
# |    7    |  1.50 |    10.33  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  1.50 |    10.64  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.90  |
# |   14    |  1.00 |    16.62  |
# |   15    |  0.50 |     9.84  |
# |   16    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 15: 9.84 u/hr
#   Station 3: 10.03 u/hr
#   Station 7: 10.33 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 12.34 u/hr, Output: 111.1 units
# ▶ Adjusted for 28% PF&D: 80.0 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.34 |    12.34  |
# |    2    |  1.12 |    12.34  |
# |    3    |  1.23 |    12.34  |
# |    4    |  1.67 |    12.34  |
# |    5    |  1.02 |    12.34  |
# |    6    |  1.05 |    12.34  |
# |    7    |  1.79 |    12.34  |
# |    8    |  0.86 |    12.34  |
# |    9    |  0.79 |    12.34  |
# |   10    |  1.74 |    12.34  |
# |   11    |  1.45 |    12.34  |
# |   12    |  0.82 |    12.34  |
# |   13    |  1.04 |    12.34  |
# |   14    |  0.74 |    12.34  |
# |   15    |  0.63 |    12.34  |
# |   16    |  0.70 |    12.34  |
#
# ----------------------------------------
#
#
# === Total Operators: 17 ===
#
# Integer Allocation:
# ▶ Throughput: 7.09 u/hr, Output: 63.8 units
# ▶ Adjusted for 28% PF&D: 46.0 units
# | Station |   Ops |  Units/hr |
# |    1    |    1  |     9.22  |
# |    2    |    1  |    10.99  |
# |    3    |    1  |    10.03  |
# |    4    |    1  |     7.38  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    1  |     7.09  |
# |   11    |    1  |     8.53  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.90  |
# |   14    |    1  |    16.62  |
# |   15    |    1  |    19.67  |
# |   16    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 10: 7.09 u/hr
#   Station 4: 7.38 u/hr
#   Station 11: 8.53 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 8.80 u/hr, Output: 79.2 units
# ▶ Adjusted for 28% PF&D: 57.0 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.00 |     9.22  |
# |    2    |  1.00 |    10.99  |
# |    3    |  1.00 |    10.03  |
# |    4    |  1.50 |    11.07  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.00 |    11.72  |
# |    7    |  1.50 |    10.33  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  1.50 |    10.64  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.90  |
# |   14    |  1.00 |    16.62  |
# |   15    |  0.50 |     9.84  |
# |   16    |  0.50 |     8.80  |
# Top 3 bottlenecks:
#   Station 16: 8.80 u/hr
#   Station 1: 9.22 u/hr
#   Station 15: 9.84 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 11.66 u/hr, Output: 104.9 units
# ▶ Adjusted for 28% PF&D: 75.5 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.26 |    11.66  |
# |    2    |  1.06 |    11.66  |
# |    3    |  1.16 |    11.66  |
# |    4    |  1.58 |    11.66  |
# |    5    |  0.96 |    11.66  |
# |    6    |  0.99 |    11.66  |
# |    7    |  1.69 |    11.66  |
# |    8    |  0.81 |    11.66  |
# |    9    |  0.75 |    11.66  |
# |   10    |  1.64 |    11.66  |
# |   11    |  1.37 |    11.66  |
# |   12    |  0.78 |    11.66  |
# |   13    |  0.98 |    11.66  |
# |   14    |  0.70 |    11.66  |
# |   15    |  0.59 |    11.66  |
# |   16    |  0.66 |    11.66  |
#
# ----------------------------------------
#
#
# === Total Operators: 16 ===
#
# Integer Allocation:
# ▶ Throughput: 6.89 u/hr, Output: 62.0 units
# ▶ Adjusted for 28% PF&D: 44.6 units
# | Station |   Ops |  Units/hr |
# |    1    |    1  |     9.22  |
# |    2    |    1  |    10.99  |
# |    3    |    1  |    10.03  |
# |    4    |    1  |     7.38  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    1  |     6.89  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    1  |     7.09  |
# |   11    |    1  |     8.53  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.90  |
# |   14    |    1  |    16.62  |
# |   15    |    1  |    19.67  |
# |   16    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 7: 6.89 u/hr
#   Station 10: 7.09 u/hr
#   Station 4: 7.38 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 8.31 u/hr, Output: 74.8 units
# ▶ Adjusted for 28% PF&D: 53.9 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.00 |     9.22  |
# |    2    |  1.00 |    10.99  |
# |    3    |  1.00 |    10.03  |
# |    4    |  1.50 |    11.07  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.00 |    11.72  |
# |    7    |  1.50 |    10.33  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  1.50 |    10.64  |
# |   11    |  1.00 |     8.53  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.90  |
# |   14    |  0.50 |     8.31  |
# |   15    |  0.50 |     9.84  |
# |   16    |  0.50 |     8.80  |
# Top 3 bottlenecks:
#   Station 14: 8.31 u/hr
#   Station 11: 8.53 u/hr
#   Station 16: 8.80 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 10.97 u/hr, Output: 98.7 units
# ▶ Adjusted for 28% PF&D: 71.1 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.19 |    10.97  |
# |    2    |  1.00 |    10.97  |
# |    3    |  1.09 |    10.97  |
# |    4    |  1.49 |    10.97  |
# |    5    |  0.91 |    10.97  |
# |    6    |  0.94 |    10.97  |
# |    7    |  1.59 |    10.97  |
# |    8    |  0.76 |    10.97  |
# |    9    |  0.70 |    10.97  |
# |   10    |  1.55 |    10.97  |
# |   11    |  1.29 |    10.97  |
# |   12    |  0.73 |    10.97  |
# |   13    |  0.92 |    10.97  |
# |   14    |  0.66 |    10.97  |
# |   15    |  0.56 |    10.97  |
# |   16    |  0.62 |    10.97  |
#
# ----------------------------------------
