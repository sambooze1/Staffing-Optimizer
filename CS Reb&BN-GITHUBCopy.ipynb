# %%
import gurobipy as gp
from gurobipy import GRB

# Data
cycle_times = [6.51,5.46,5.98,8.13,4.96,5.12,8.71,4.17,3.85,8.46,7.03,4.01,5.08,5.37,6.05,4.6,9.22,5.58,7.43,3.53,5.09,4,3.61,3.05,3.41
               ]
operator_counts = [38,37,36,35,34]
shift_hours = 9
n = len(cycle_times)

for total_ops in operator_counts:
    print(f'\n=== Total Operators: {total_ops} ===\n')
    
    # 1) Integer allocation
    m_int = gp.Model(f'Int_Alloc_{total_ops}')
    m_int.Params.OutputFlag = 0
    ops_int = m_int.addVars(n, vtype=GRB.INTEGER, lb=1, name='ops_int')
    mu_int = m_int.addVar(vtype=GRB.CONTINUOUS, name='mu_int')
    for i, T in enumerate(cycle_times):
        m_int.addConstr(60 * ops_int[i] >= mu_int * T)
    m_int.addConstr(ops_int.sum() == total_ops)
    m_int.setObjective(mu_int, GRB.MAXIMIZE)
    m_int.optimize()
    thr_int = mu_int.X
    daily_int = thr_int * shift_hours
    adj_daily_int = 0.72 * daily_int
    rates_int = [60 * ops_int[i].X / cycle_times[i] for i in range(n)]
    print('Integer Allocation:')
    print(f'▶ Throughput: {thr_int:.2f} u/hr, Output: {daily_int:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_int:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        print(f'|   {i+1:>2}    |  {int(ops_int[i].X):>3}  |   {rates_int[i]:>6.2f}  |')
    top3_int = sorted(range(n), key=lambda i: rates_int[i])[:3]
    print('Top 3 bottlenecks:')
    for idx in top3_int:
        print(f'  Station {idx+1}: {rates_int[idx]:.2f} u/hr')
    
    print('\n')
    
    # 2) Half-allocation
    m_half = gp.Model(f'Half_Alloc_{total_ops}')
    m_half.Params.OutputFlag = 0
    h_ops = m_half.addVars(n, vtype=GRB.INTEGER, lb=1, name='h_ops')
    mu_half = m_half.addVar(vtype=GRB.CONTINUOUS, name='mu_half')
    for i, T in enumerate(cycle_times):
        m_half.addConstr(60 * h_ops[i] >= mu_half * (2 * T))
    m_half.addConstr(h_ops.sum() == total_ops * 2)
    m_half.setObjective(mu_half, GRB.MAXIMIZE)
    m_half.optimize()
    thr_half = mu_half.X
    daily_half = thr_half * shift_hours
    adj_daily_half = 0.72 * daily_half
    rates_half = [(60 * (h_ops[i].X / 2)) / cycle_times[i] for i in range(n)]
    print('Half Allocation:')
    print(f'▶ Throughput: {thr_half:.2f} u/hr, Output: {daily_half:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_half:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        ops_val = h_ops[i].X / 2
        print(f'|   {i+1:>2}    | {ops_val:>5.2f} |   {rates_half[i]:>6.2f}  |')
    top3_half = sorted(range(n), key=lambda i: rates_half[i])[:3]
    print('Top 3 bottlenecks:')
    for idx in top3_half:
        print(f'  Station {idx+1}: {rates_half[idx]:.2f} u/hr')
    
    print('\n')
    
    # 3) Fractional allocation
    m_frac = gp.Model(f'Frac_Alloc_{total_ops}')
    m_frac.Params.OutputFlag = 0
    ops_frac = m_frac.addVars(n, vtype=GRB.CONTINUOUS, lb=0, name='ops_frac')
    mu_frac = m_frac.addVar(vtype=GRB.CONTINUOUS, name='mu_frac')
    for i, T in enumerate(cycle_times):
        m_frac.addConstr(60 * ops_frac[i] >= mu_frac * T)
    m_frac.addConstr(ops_frac.sum() == total_ops)
    m_frac.setObjective(mu_frac, GRB.MAXIMIZE)
    m_frac.optimize()
    thr_frac = mu_frac.X
    daily_frac = thr_frac * shift_hours
    adj_daily_frac = 0.72 * daily_frac
    rates_frac = [60 * ops_frac[i].X / cycle_times[i] for i in range(n)]
    print('Fractional Allocation:')
    print(f'▶ Throughput: {thr_frac:.2f} u/hr, Output: {daily_frac:.1f} units')
    print(f'▶ Adjusted for 28% PF&D: {adj_daily_frac:.1f} units')
    print('| Station |   Ops |  Units/hr |')
    for i in range(n):
        print(f'|   {i+1:>2}    | {ops_frac[i].X:>5.2f} |   {rates_frac[i]:>6.2f}  |')
    
    print('\n' + '-'*40 + '\n')
# Out:
# === Total Operators: 38 ===
#
# Set parameter Username
# Set parameter LicenseID to value 2663177
# Academic license - for non-commercial use only - expires 2026-05-09
# Integer Allocation:
# ▶ Throughput: 11.79 u/hr, Output: 106.1 units
# ▶ Adjusted for 28% PF&D: 76.4 units
# | Station |   Ops |  Units/hr |
# |    1    |    2  |    18.43  |
# |    2    |    2  |    21.98  |
# |    3    |    2  |    20.07  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    2  |    23.44  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.81  |
# |   14    |    2  |    22.35  |
# |   15    |    2  |    19.83  |
# |   16    |    1  |    13.04  |
# |   17    |    2  |    13.02  |
# |   18    |    2  |    21.51  |
# |   19    |    2  |    16.15  |
# |   20    |    1  |    17.00  |
# |   21    |    1  |    11.79  |
# |   22    |    1  |    15.00  |
# |   23    |    1  |    16.62  |
# |   24    |    1  |    19.67  |
# |   25    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 21: 11.79 u/hr
#   Station 13: 11.81 u/hr
#   Station 5: 12.10 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 14.18 u/hr, Output: 127.7 units
# ▶ Adjusted for 28% PF&D: 91.9 units
# | Station |   Ops |  Units/hr |
# |    1    |  2.00 |    18.43  |
# |    2    |  1.50 |    16.48  |
# |    3    |  1.50 |    15.05  |
# |    4    |  2.00 |    14.76  |
# |    5    |  1.50 |    18.15  |
# |    6    |  1.50 |    17.58  |
# |    7    |  2.50 |    17.22  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  2.00 |    17.07  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.50 |    17.72  |
# |   14    |  1.50 |    16.76  |
# |   15    |  1.50 |    14.88  |
# |   16    |  1.50 |    19.57  |
# |   17    |  2.50 |    16.27  |
# |   18    |  1.50 |    16.13  |
# |   19    |  2.00 |    16.15  |
# |   20    |  1.00 |    17.00  |
# |   21    |  1.50 |    17.68  |
# |   22    |  1.00 |    15.00  |
# |   23    |  1.00 |    16.62  |
# |   24    |  1.00 |    19.67  |
# |   25    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 10: 14.18 u/hr
#   Station 8: 14.39 u/hr
#   Station 4: 14.76 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 16.47 u/hr, Output: 148.3 units
# ▶ Adjusted for 28% PF&D: 106.7 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.79 |    16.47  |
# |    2    |  1.50 |    16.47  |
# |    3    |  1.64 |    16.47  |
# |    4    |  2.23 |    16.47  |
# |    5    |  1.36 |    16.47  |
# |    6    |  1.41 |    16.47  |
# |    7    |  2.39 |    16.47  |
# |    8    |  1.14 |    16.47  |
# |    9    |  1.06 |    16.47  |
# |   10    |  2.32 |    16.47  |
# |   11    |  1.93 |    16.47  |
# |   12    |  1.10 |    16.47  |
# |   13    |  1.39 |    16.47  |
# |   14    |  1.47 |    16.47  |
# |   15    |  1.66 |    16.47  |
# |   16    |  1.26 |    16.47  |
# |   17    |  2.53 |    16.47  |
# |   18    |  1.53 |    16.47  |
# |   19    |  2.04 |    16.47  |
# |   20    |  0.97 |    16.47  |
# |   21    |  1.40 |    16.47  |
# |   22    |  1.10 |    16.47  |
# |   23    |  0.99 |    16.47  |
# |   24    |  0.84 |    16.47  |
# |   25    |  0.94 |    16.47  |
#
# ----------------------------------------
#
#
# === Total Operators: 37 ===
#
# Integer Allocation:
# ▶ Throughput: 11.72 u/hr, Output: 105.5 units
# ▶ Adjusted for 28% PF&D: 75.9 units
# | Station |   Ops |  Units/hr |
# |    1    |    2  |    18.43  |
# |    2    |    2  |    21.98  |
# |    3    |    2  |    20.07  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.81  |
# |   14    |    2  |    22.35  |
# |   15    |    2  |    19.83  |
# |   16    |    1  |    13.04  |
# |   17    |    2  |    13.02  |
# |   18    |    2  |    21.51  |
# |   19    |    2  |    16.15  |
# |   20    |    1  |    17.00  |
# |   21    |    1  |    11.79  |
# |   22    |    1  |    15.00  |
# |   23    |    1  |    16.62  |
# |   24    |    1  |    19.67  |
# |   25    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 6: 11.72 u/hr
#   Station 21: 11.79 u/hr
#   Station 13: 11.81 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 13.78 u/hr, Output: 124.0 units
# ▶ Adjusted for 28% PF&D: 89.3 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.50 |    16.48  |
# |    3    |  1.50 |    15.05  |
# |    4    |  2.00 |    14.76  |
# |    5    |  1.50 |    18.15  |
# |    6    |  1.50 |    17.58  |
# |    7    |  2.00 |    13.78  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  2.00 |    17.07  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.50 |    17.72  |
# |   14    |  1.50 |    16.76  |
# |   15    |  1.50 |    14.88  |
# |   16    |  1.50 |    19.57  |
# |   17    |  2.50 |    16.27  |
# |   18    |  1.50 |    16.13  |
# |   19    |  2.00 |    16.15  |
# |   20    |  1.00 |    17.00  |
# |   21    |  1.50 |    17.68  |
# |   22    |  1.00 |    15.00  |
# |   23    |  1.00 |    16.62  |
# |   24    |  1.00 |    19.67  |
# |   25    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 7: 13.78 u/hr
#   Station 1: 13.82 u/hr
#   Station 10: 14.18 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 16.04 u/hr, Output: 144.4 units
# ▶ Adjusted for 28% PF&D: 103.9 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.74 |    16.04  |
# |    2    |  1.46 |    16.04  |
# |    3    |  1.60 |    16.04  |
# |    4    |  2.17 |    16.04  |
# |    5    |  1.33 |    16.04  |
# |    6    |  1.37 |    16.04  |
# |    7    |  2.33 |    16.04  |
# |    8    |  1.11 |    16.04  |
# |    9    |  1.03 |    16.04  |
# |   10    |  2.26 |    16.04  |
# |   11    |  1.88 |    16.04  |
# |   12    |  1.07 |    16.04  |
# |   13    |  1.36 |    16.04  |
# |   14    |  1.44 |    16.04  |
# |   15    |  1.62 |    16.04  |
# |   16    |  1.23 |    16.04  |
# |   17    |  2.46 |    16.04  |
# |   18    |  1.49 |    16.04  |
# |   19    |  1.99 |    16.04  |
# |   20    |  0.94 |    16.04  |
# |   21    |  1.36 |    16.04  |
# |   22    |  1.07 |    16.04  |
# |   23    |  0.97 |    16.04  |
# |   24    |  0.82 |    16.04  |
# |   25    |  0.91 |    16.04  |
#
# ----------------------------------------
#
#
# === Total Operators: 36 ===
#
# Integer Allocation:
# ▶ Throughput: 11.17 u/hr, Output: 100.6 units
# ▶ Adjusted for 28% PF&D: 72.4 units
# | Station |   Ops |  Units/hr |
# |    1    |    2  |    18.43  |
# |    2    |    2  |    21.98  |
# |    3    |    2  |    20.07  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.81  |
# |   14    |    1  |    11.17  |
# |   15    |    2  |    19.83  |
# |   16    |    1  |    13.04  |
# |   17    |    2  |    13.02  |
# |   18    |    2  |    21.51  |
# |   19    |    2  |    16.15  |
# |   20    |    1  |    17.00  |
# |   21    |    1  |    11.79  |
# |   22    |    1  |    15.00  |
# |   23    |    1  |    16.62  |
# |   24    |    1  |    19.67  |
# |   25    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 14: 11.17 u/hr
#   Station 6: 11.72 u/hr
#   Station 21: 11.79 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 13.02 u/hr, Output: 117.1 units
# ▶ Adjusted for 28% PF&D: 84.3 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.50 |    16.48  |
# |    3    |  1.50 |    15.05  |
# |    4    |  2.00 |    14.76  |
# |    5    |  1.50 |    18.15  |
# |    6    |  1.50 |    17.58  |
# |    7    |  2.00 |    13.78  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  2.00 |    17.07  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.50 |    17.72  |
# |   14    |  1.50 |    16.76  |
# |   15    |  1.50 |    14.88  |
# |   16    |  1.00 |    13.04  |
# |   17    |  2.00 |    13.02  |
# |   18    |  1.50 |    16.13  |
# |   19    |  2.00 |    16.15  |
# |   20    |  1.00 |    17.00  |
# |   21    |  1.50 |    17.68  |
# |   22    |  1.00 |    15.00  |
# |   23    |  1.00 |    16.62  |
# |   24    |  1.00 |    19.67  |
# |   25    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 17: 13.02 u/hr
#   Station 16: 13.04 u/hr
#   Station 7: 13.78 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 15.61 u/hr, Output: 140.5 units
# ▶ Adjusted for 28% PF&D: 101.1 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.69 |    15.61  |
# |    2    |  1.42 |    15.61  |
# |    3    |  1.56 |    15.61  |
# |    4    |  2.11 |    15.61  |
# |    5    |  1.29 |    15.61  |
# |    6    |  1.33 |    15.61  |
# |    7    |  2.27 |    15.61  |
# |    8    |  1.08 |    15.61  |
# |    9    |  1.00 |    15.61  |
# |   10    |  2.20 |    15.61  |
# |   11    |  1.83 |    15.61  |
# |   12    |  1.04 |    15.61  |
# |   13    |  1.32 |    15.61  |
# |   14    |  1.40 |    15.61  |
# |   15    |  1.57 |    15.61  |
# |   16    |  1.20 |    15.61  |
# |   17    |  2.40 |    15.61  |
# |   18    |  1.45 |    15.61  |
# |   19    |  1.93 |    15.61  |
# |   20    |  0.92 |    15.61  |
# |   21    |  1.32 |    15.61  |
# |   22    |  1.04 |    15.61  |
# |   23    |  0.94 |    15.61  |
# |   24    |  0.79 |    15.61  |
# |   25    |  0.89 |    15.61  |
#
# ----------------------------------------
#
#
# === Total Operators: 35 ===
#
# Integer Allocation:
# ▶ Throughput: 10.99 u/hr, Output: 98.9 units
# ▶ Adjusted for 28% PF&D: 71.2 units
# | Station |   Ops |  Units/hr |
# |    1    |    2  |    18.43  |
# |    2    |    1  |    10.99  |
# |    3    |    2  |    20.07  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.81  |
# |   14    |    1  |    11.17  |
# |   15    |    2  |    19.83  |
# |   16    |    1  |    13.04  |
# |   17    |    2  |    13.02  |
# |   18    |    2  |    21.51  |
# |   19    |    2  |    16.15  |
# |   20    |    1  |    17.00  |
# |   21    |    1  |    11.79  |
# |   22    |    1  |    15.00  |
# |   23    |    1  |    16.62  |
# |   24    |    1  |    19.67  |
# |   25    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 2: 10.99 u/hr
#   Station 14: 11.17 u/hr
#   Station 6: 11.72 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 12.11 u/hr, Output: 109.0 units
# ▶ Adjusted for 28% PF&D: 78.5 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.50 |    16.48  |
# |    3    |  1.50 |    15.05  |
# |    4    |  2.00 |    14.76  |
# |    5    |  1.50 |    18.15  |
# |    6    |  1.50 |    17.58  |
# |    7    |  2.00 |    13.78  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.50 |    17.72  |
# |   14    |  1.50 |    16.76  |
# |   15    |  1.50 |    14.88  |
# |   16    |  1.00 |    13.04  |
# |   17    |  2.00 |    13.02  |
# |   18    |  1.50 |    16.13  |
# |   19    |  1.50 |    12.11  |
# |   20    |  1.00 |    17.00  |
# |   21    |  1.50 |    17.68  |
# |   22    |  1.00 |    15.00  |
# |   23    |  1.00 |    16.62  |
# |   24    |  1.00 |    19.67  |
# |   25    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 19: 12.11 u/hr
#   Station 11: 12.80 u/hr
#   Station 17: 13.02 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 15.17 u/hr, Output: 136.6 units
# ▶ Adjusted for 28% PF&D: 98.3 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.65 |    15.17  |
# |    2    |  1.38 |    15.17  |
# |    3    |  1.51 |    15.17  |
# |    4    |  2.06 |    15.17  |
# |    5    |  1.25 |    15.17  |
# |    6    |  1.29 |    15.17  |
# |    7    |  2.20 |    15.17  |
# |    8    |  1.05 |    15.17  |
# |    9    |  0.97 |    15.17  |
# |   10    |  2.14 |    15.17  |
# |   11    |  1.78 |    15.17  |
# |   12    |  1.01 |    15.17  |
# |   13    |  1.28 |    15.17  |
# |   14    |  1.36 |    15.17  |
# |   15    |  1.53 |    15.17  |
# |   16    |  1.16 |    15.17  |
# |   17    |  2.33 |    15.17  |
# |   18    |  1.41 |    15.17  |
# |   19    |  1.88 |    15.17  |
# |   20    |  0.89 |    15.17  |
# |   21    |  1.29 |    15.17  |
# |   22    |  1.01 |    15.17  |
# |   23    |  0.91 |    15.17  |
# |   24    |  0.77 |    15.17  |
# |   25    |  0.86 |    15.17  |
#
# ----------------------------------------
#
#
# === Total Operators: 34 ===
#
# Integer Allocation:
# ▶ Throughput: 10.75 u/hr, Output: 96.8 units
# ▶ Adjusted for 28% PF&D: 69.7 units
# | Station |   Ops |  Units/hr |
# |    1    |    2  |    18.43  |
# |    2    |    1  |    10.99  |
# |    3    |    2  |    20.07  |
# |    4    |    2  |    14.76  |
# |    5    |    1  |    12.10  |
# |    6    |    1  |    11.72  |
# |    7    |    2  |    13.78  |
# |    8    |    1  |    14.39  |
# |    9    |    1  |    15.58  |
# |   10    |    2  |    14.18  |
# |   11    |    2  |    17.07  |
# |   12    |    1  |    14.96  |
# |   13    |    1  |    11.81  |
# |   14    |    1  |    11.17  |
# |   15    |    2  |    19.83  |
# |   16    |    1  |    13.04  |
# |   17    |    2  |    13.02  |
# |   18    |    1  |    10.75  |
# |   19    |    2  |    16.15  |
# |   20    |    1  |    17.00  |
# |   21    |    1  |    11.79  |
# |   22    |    1  |    15.00  |
# |   23    |    1  |    16.62  |
# |   24    |    1  |    19.67  |
# |   25    |    1  |    17.60  |
# Top 3 bottlenecks:
#   Station 18: 10.75 u/hr
#   Station 2: 10.99 u/hr
#   Station 14: 11.17 u/hr
#
#
# Half Allocation:
# ▶ Throughput: 11.81 u/hr, Output: 106.3 units
# ▶ Adjusted for 28% PF&D: 76.5 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.50 |    13.82  |
# |    2    |  1.50 |    16.48  |
# |    3    |  1.50 |    15.05  |
# |    4    |  2.00 |    14.76  |
# |    5    |  1.00 |    12.10  |
# |    6    |  1.50 |    17.58  |
# |    7    |  2.00 |    13.78  |
# |    8    |  1.00 |    14.39  |
# |    9    |  1.00 |    15.58  |
# |   10    |  2.00 |    14.18  |
# |   11    |  1.50 |    12.80  |
# |   12    |  1.00 |    14.96  |
# |   13    |  1.00 |    11.81  |
# |   14    |  1.50 |    16.76  |
# |   15    |  1.50 |    14.88  |
# |   16    |  1.00 |    13.04  |
# |   17    |  2.00 |    13.02  |
# |   18    |  1.50 |    16.13  |
# |   19    |  1.50 |    12.11  |
# |   20    |  1.00 |    17.00  |
# |   21    |  1.50 |    17.68  |
# |   22    |  1.00 |    15.00  |
# |   23    |  1.00 |    16.62  |
# |   24    |  1.00 |    19.67  |
# |   25    |  1.00 |    17.60  |
# Top 3 bottlenecks:
#   Station 13: 11.81 u/hr
#   Station 5: 12.10 u/hr
#   Station 19: 12.11 u/hr
#
#
# Fractional Allocation:
# ▶ Throughput: 14.74 u/hr, Output: 132.6 units
# ▶ Adjusted for 28% PF&D: 95.5 units
# | Station |   Ops |  Units/hr |
# |    1    |  1.60 |    14.74  |
# |    2    |  1.34 |    14.74  |
# |    3    |  1.47 |    14.74  |
# |    4    |  2.00 |    14.74  |
# |    5    |  1.22 |    14.74  |
# |    6    |  1.26 |    14.74  |
# |    7    |  2.14 |    14.74  |
# |    8    |  1.02 |    14.74  |
# |    9    |  0.95 |    14.74  |
# |   10    |  2.08 |    14.74  |
# |   11    |  1.73 |    14.74  |
# |   12    |  0.99 |    14.74  |
# |   13    |  1.25 |    14.74  |
# |   14    |  1.32 |    14.74  |
# |   15    |  1.49 |    14.74  |
# |   16    |  1.13 |    14.74  |
# |   17    |  2.26 |    14.74  |
# |   18    |  1.37 |    14.74  |
# |   19    |  1.83 |    14.74  |
# |   20    |  0.87 |    14.74  |
# |   21    |  1.25 |    14.74  |
# |   22    |  0.98 |    14.74  |
# |   23    |  0.89 |    14.74  |
# |   24    |  0.75 |    14.74  |
# |   25    |  0.84 |    14.74  |
#
# ----------------------------------------
